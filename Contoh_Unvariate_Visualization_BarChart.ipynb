# %% [markdown]
# <a href="https://colab.research.google.com/github/nrmlptr/Analisis-Data-Dengan-Python/blob/main/Contoh_Unvariate_Visualization_BarChart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# visualisasi data dengan bar chart
import matplotlib.pyplot as plt

cities=('Bogor', 'Bandung', 'Jakarta', 'Semarang', 'Yogyakarta', 'Surakarta',
        'Surabaya', 'Medan', 'Makassar')

population = (45076704, 11626410, 212162757, 19109629, 50819826, 17579085,
               3481, 287750, 785409)

# plt.bar(x=cities, height=population)
# plt.show()

# modifikasi agar sumbu x bisa dibaca menggunakan fungsi xticks()
# dan mengatur parameter rotation (mengatur besar rotasi nilai di sumbu x)
plt.bar(x=cities, height=population)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# adapun fungsi barh(). tetapi perlu mendefinisikan parameter y dan width dari bar chart yang ingin dibuat..

# %%
# visualisasi data dengan bar chart
import matplotlib.pyplot as plt

cities=('Bogor', 'Bandung', 'Jakarta', 'Semarang', 'Yogyakarta', 'Surakarta',
        'Surabaya', 'Medan', 'Makassar')

population = (45076704, 11626410, 212162757, 19109629, 50819826, 17579085,
               3481, 287750, 785409)


plt.barh(y=cities, width=population)
plt.show()

# %% [markdown]
# Dari hasil diatas, data tersebut merupakan data nominal sehingga dapat kita urutkan nilainya berdasarkan jumlah populasi terbanyak. Untuk melakukan hal ini, perlu bantuan library pandas dalam mengubah data menjadi DataFrame dan mengurutkannya menggunakan function sort_values().

# %%
import pandas as pd

df = pd.DataFrame({
    'Cities': cities,
    'Population': population,
})

df.sort_values(by='Population', inplace=True)

plt.barh(y=df["Cities"], width=df["Population"])
plt.show()

# %% [markdown]
# Untuk memperjelas visualisasi data yang dibuat, bisa juga dibuatkan beberapa keterangan seperti judul dan keterangan sumbu. Untuk melakukan hal ini, bisa menggunakan function title(), xlabel(), dan ylabel().

# %%
import pandas as pd

df = pd.DataFrame({
    'Cities': cities,
    'Population': population,
})

df.sort_values(by='Population', inplace=True)

plt.barh(y=df["Cities"], width=df["Population"])
plt.xlabel("Population (Million)")
plt.title("Population of Cities in Indonesia")
plt.show()

# %% [markdown]
# LIBRARY SEABORN
# Untuk membuat bar chart menggunakan library seaborn, bisa menggunakan function barplot(). Function ini akan menyediakan beberapa parameter penting seperti berikut.
#
# data: menampung DataFrame yang akan digunakan.
# x, y: menampung nama kolom atau data yang divisualisasikan.
# orient: orientasi dari bar chart yang akan digunakan (“v” atau “h”).
# color: mendefinisikan warna yang akan digunakan.

# %%
import seaborn as sns

sns.barplot(y=df["Cities"], x=df["Population"], orient="h", color='blue')
plt.xlabel("Population (Million)")
plt.title("Population of Cities in Indonesia")
plt.show()
